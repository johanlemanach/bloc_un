# %%
import os
import requests
from dotenv import load_dotenv
from requests.auth import HTTPBasicAuth

load_dotenv()

BASE_URL = "http://127.0.0.1:8000"
USERNAME = os.getenv("USERNAME")
PASSWORD = os.getenv("PASSWORD")

print(f"Username: {USERNAME}, Password: {PASSWORD}")

def login(username: str, password: str):
    """Effectuer une connexion et obtenir un token JWT
    arguments:
        username -- nom d'utilisateur
        password -- mot de passe
    returns:
        token -- token JWT"""
        
    login_url = f"{BASE_URL}/login"
    response = requests.post(login_url, data={"username": username, "password": password})
    
    if response.status_code == 200:
        token = response.json().get("access_token")
        print(f"Token JWT : {token}")
        return token
    else:
        print(f"Erreur de connexion: {response.text}")
        return None
    

def test_protected_route(token: str):
    """Tester la route protégée
    arguments:
        token -- token JWT"""
        
    protected_url = f"{BASE_URL}/protected"
    headers = {"Authorization": f"Bearer {token}"}
    response = requests.get(protected_url, headers=headers)

    if response.status_code == 200:
        print(f"Réponse de la route protégée: {response.json()}")
    else:
        print(f"Erreur dans la route protégée: {response.text}")


def test_get_recipes_by_category(category: str):
    """Tester la récupération des recettes par catégorie
    returns:
        recettes -- liste des recettes de la catégorie"""
    url = f"{BASE_URL}/recettes/{category}"
    response = requests.get(url)

    if response.status_code == 200:
        print(f"Recettes de la catégorie {category}: {response.json()}")
    else:
        print(f"Erreur dans la récupération des recettes: {response.text}")


def test_get_recipe_by_id(recipe_id: str):
    """Tester la récupération d'une recette par ID
    arguments:
        recipe_id -- ID de la recette
    returns:
        recette -- recette avec l'ID donné"""
        
    url = f"{BASE_URL}/recette/{recipe_id}"
    response = requests.get(url)

    if response.status_code == 200:
        print(f"Recette avec l'ID {recipe_id}: {response.json()}")
    else:
        print(f"Erreur dans la récupération de la recette: {response.text}")


def test_get_all_sandwiches():
    """Tester la récupération de tous les sandwiches
    returns:
        sandwiches -- liste des sandwiches"""
        
    url = f"{BASE_URL}/sandwiches"
    response = requests.get(url)

    if response.status_code == 200:
        print(f"Sandwichs: {response.json()}")
    else:
        print(f"Erreur dans la récupération des sandwiches: {response.text}")


def test_get_ingredients_with_nutrients(ingredient_name: str):
    """Tester la récupération des valeurs nutritionnelles d'un ingrédient
    arguments:
        ingredient_name -- nom de l'ingrédient
    returns:
        nutriments -- valeurs nutritionnelles de l'ingrédient"""
        
    url = f"{BASE_URL}/ingredients/{ingredient_name}"
    response = requests.get(url)

    if response.status_code == 200:
        print(f"Ingrédient {ingredient_name}: {response.json()}")
    else:
        print(f"Erreur dans la récupération des nutriments: {response.text}")


def run_tests():
    """Exécuter les tests"""
    token = login(USERNAME, PASSWORD)
    if token:
        test_protected_route(token)
        test_get_recipes_by_category('vegan')
        test_get_recipe_by_id("67c9b973fcfe30442a39850d")
        test_get_all_sandwiches()
        test_get_ingredients_with_nutrients("tomate")

run_tests()
# Out:
# Username: testuser, Password: password123
# Token JWT : eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJzdWIiOiJ0ZXN0dXNlciIsImV4cCI6MTc0MTM2MDk1N30.QLtCxCP4Sgmo_KjjngUCh_dYfKVHbyOkpe3or5ySFfE
# Réponse de la route protégée: {'message': 'Bienvenue testuser sur la route protéger'}
# Recettes de la catégorie vegan: {'category': 'vegan', 'recipes': [{'_id': '67c9b973fcfe30442a39850c', 'title': 'Falafel (croquettes de pois chiches)', 'category': 'Vegan', 'prep_time': '1h20', 'repos': '-', 'cuisson': '20 min', 'image_url': 'Image non trouvée', 'ingredients': [{'name': 'huile de friture', 'quantity': '', 'unit': '', 'complement': ''}, {'name': 'sel', 'quantity': '', 'unit': '', 'complement': ''}, {'name': 'coriandre', 'quantity': '1', 'unit': 'cuillere a cafe', 'complement': 'en poudre'}, {'name': 'cumin en poudre', 'quantity': '1', 'unit': 'cuillere a cafe', 'complement': ''}, {'name': 'farine', 'quantity': '3', 'unit': 'cuilleres a soupe', 'complement': ''}, {'name': 'persil', 'quantity': '1', 'unit': 'bouquet', 'complement': ''}, {'name': 'oignon', 'quantity': '1', 'unit': '', 'complement': 'moyen'}, {'name': 'pois chiches', 'quantity': '200', 'unit': 'g', 'complement': ''}, {'name': 'feves', 'quantity': '500', 'unit': 'g', 'complement': 'sèches'}, {'name': 'ail', 'quantity': '2', 'unit': 'gousses', 'complement': ''}, {'name': 'paprika', 'quantity': '1', 'unit': 'cuillere a cafe', 'complement': ''}, {'name': 'basilic frais', 'quantity': '3', 'unit': 'cuilleres a soupe', 'complement': 'haché'}], 'steps': ["Faites tremper les pois chiches et les fèves dans l'eau 12 h, les égoutter et les cuire 45 mn à l'auto cuiseur.", 'Peler oignon et ail, les hacher ainsi que le persil.', 'Passer les fèves et les pois chiches au mixer (ou robot).', "Mélanger avec le persil, l'oignon, l'ail, la farine, les épices, le sel.", "Pétrissez le tout avec vos mains en ajoutant un peu d'eau si nécessaire. Rassemblez la pâte et laisser reposer au réfrigérateur pendant minimum 30 mn.", "Façonner une trentaine de boulettes de la grosseur d'une pièce de 2 euros.", 'Les faire frire 2/3 mn puis les égoutter sur du papier absorbant.', 'Servir chaud ou froid avec des petites sauces tomates aux herbes, ou sauces yaourts.']}, {'_id': '67c9b973fcfe30442a39850d', 'title': 'Samossas de légumes', 'category': 'Vegan', 'prep_time': '1 h', 'repos': '-', 'cuisson': '35 min', 'image_url': None, 'ingredients': [{'name': 'coriandre', 'quantity': '2', 'unit': 'cuilleres a soupe', 'complement': 'ciselée'}, {'name': 'cumin', 'quantity': '1', 'unit': 'cuillere a cafe', 'complement': ''}, {'name': 'poivron rouge', 'quantity': '1', 'unit': '', 'complement': 'coupé en dés'}, {'name': 'carotte', 'quantity': '175', 'unit': 'g', 'complement': 'coupées en dés'}, {'name': 'oignon', 'quantity': '1', 'unit': '', 'complement': ''}, {'name': 'huile', 'quantity': '20', 'unit': 'cl', 'complement': ''}, {'name': 'ail', 'quantity': '1', 'unit': 'gousse', 'complement': 'écrasée'}, {'name': 'pomme de terre', 'quantity': '225', 'unit': 'g', 'complement': 'coupées en dés'}, {'name': 'petits pois', 'quantity': '100', 'unit': 'g', 'complement': ''}, {'name': 'pate de curry', 'quantity': '2', 'unit': 'cuilleres a soupe', 'complement': ''}, {'name': 'chutney', 'quantity': '3', 'unit': 'cuilleres a soupe', 'complement': 'de mangue'}, {'name': 'filo', 'quantity': '16', 'unit': 'feuilles', 'complement': ''}], 'steps': ["Dans une poêle, chauffer 2 cuillers à soupe d'huile.", "Faire revenir l'oignon et l'ail 1 min. Ajouter les carottes, les pommes de terre et le poivron. Remuer 5 min.", 'Ajouter le cumin et la pâte de curry. Remuer 2 min.', "Délayer avec 4 cuiller à soupe d'eau, couvrir et laisser mijoter 5 min à feu doux.", 'Incorporer les petits pois, le chutney et la coriandre. Oter du feu.', 'Couper les feuilles de filo en deux dans la longueur. Les huiler au pinceau.', 'Déposer un peu de farce dans un coin et refermer en triangle.', "Faire dorer les samosas 5 par 5 dans le reste d'huile bouillante, 2 min de chaque côté et bien les égoutter."]}, {'_id': '67c9b973fcfe30442a39850e', 'title': 'Salade de quinoa', 'category': 'Vegan', 'prep_time': '30 min', 'repos': '-', 'cuisson': '15 min', 'image_url': 'Image non trouvée', 'ingredients': [{'name': 'sel', 'quantity': '', 'unit': '', 'co ...
# Recette avec l'ID 67c9b973fcfe30442a39850d: {'recipe': {'_id': '67c9b973fcfe30442a39850d', 'title': 'Samossas de légumes', 'category': 'Vegan', 'prep_time': '1 h', 'repos': '-', 'cuisson': '35 min', 'image_url': None, 'ingredients': [{'name': 'coriandre', 'quantity': '2', 'unit': 'cuilleres a soupe', 'complement': 'ciselée'}, {'name': 'cumin', 'quantity': '1', 'unit': 'cuillere a cafe', 'complement': ''}, {'name': 'poivron rouge', 'quantity': '1', 'unit': '', 'complement': 'coupé en dés'}, {'name': 'carotte', 'quantity': '175', 'unit': 'g', 'complement': 'coupées en dés'}, {'name': 'oignon', 'quantity': '1', 'unit': '', 'complement': ''}, {'name': 'huile', 'quantity': '20', 'unit': 'cl', 'complement': ''}, {'name': 'ail', 'quantity': '1', 'unit': 'gousse', 'complement': 'écrasée'}, {'name': 'pomme de terre', 'quantity': '225', 'unit': 'g', 'complement': 'coupées en dés'}, {'name': 'petits pois', 'quantity': '100', 'unit': 'g', 'complement': ''}, {'name': 'pate de curry', 'quantity': '2', 'unit': 'cuilleres a soupe', 'complement': ''}, {'name': 'chutney', 'quantity': '3', 'unit': 'cuilleres a soupe', 'complement': 'de mangue'}, {'name': 'filo', 'quantity': '16', 'unit': 'feuilles', 'complement': ''}], 'steps': ["Dans une poêle, chauffer 2 cuillers à soupe d'huile.", "Faire revenir l'oignon et l'ail 1 min. Ajouter les carottes, les pommes de terre et le poivron. Remuer 5 min.", 'Ajouter le cumin et la pâte de curry. Remuer 2 min.', "Délayer avec 4 cuiller à soupe d'eau, couvrir et laisser mijoter 5 min à feu doux.", 'Incorporer les petits pois, le chutney et la coriandre. Oter du feu.', 'Couper les feuilles de filo en deux dans la longueur. Les huiler au pinceau.', 'Déposer un peu de farce dans un coin et refermer en triangle.', "Faire dorer les samosas 5 par 5 dans le reste d'huile bouillante, 2 min de chaque côté et bien les égoutter."]}, 'ingredient_names': ['coriandre', 'cumin', 'poivron rouge', 'carotte', 'oignon', 'huile', 'ail', 'pomme de terre', 'petits pois', 'pate de curry', 'chutney', 'filo']}
# Sandwichs: {'sandwiches': [{'sandwich': 'A1 Ultimate Cheeseburger', '_id': '67c9be88387e701279a70639', 'ingredients': ['A.1. Steak Sauce', 'American cheese', 'ground beef', 'White onion', 'bacon']}, {'sandwich': 'Albuquerque turkey', '_id': '67c9be88387e701279a7063a', 'ingredients': ['turkey meat', 'New Mexico chile', 'cheese']}, {'sandwich': "alligator po' boy", '_id': '67c9be89387e701279a7063b', 'ingredients': ['lettuce', 'lettuce', 'mayonnaise', 'mayonnaise', 'Alligator', 'Alligator', 'pickle', 'pickle', 'tomato', 'tomato']}, {'sandwich': 'almussafes', '_id': '67c9be89387e701279a7063c', 'ingredients': ['Sobrassada', 'Allium cepa', 'cheese']}, {'sandwich': 'angel cake', '_id': '67c9be89387e701279a7063d', 'ingredients': ['flour']}, {'sandwich': 'anko and butter sandwich', '_id': '67c9be89387e701279a7063e', 'ingredients': ['red bean paste', 'butter']}, {'sandwich': 'avocado toast', '_id': '67c9be89387e701279a7063f', 'ingredients': ['avocado']}, {'sandwich': 'Bacon Deluxe', '_id': '67c9be89387e701279a70640', 'ingredients': ['bacon']}, {'sandwich': 'bacon sandwich', '_id': '67c9be89387e701279a70641', 'ingredients': ['bacon']}, {'sandwich': 'bacon, egg and cheese sandwich', '_id': '67c9be89387e701279a70642', 'ingredients': ['chicken egg', 'bacon', 'cheese']}, {'sandwich': 'Baconator', '_id': '67c9be8a387e701279a70643', 'ingredients': ['mayonnaise', 'ketchup', 'beef', 'American cheese', 'bacon']}, {'sandwich': 'balık-ekmek', '_id': '67c9be8a387e701279a70644', 'ingredients': ['fish as food']}, {'sandwich': 'Barros Jarpa', '_id': '67c9be8a387e701279a70645', 'ingredients': ['ham', 'cheese']}, {'sandwich': 'beef burger', '_id': '67c9be8a387e701279a70646', 'ingredients': ['beef']}, {'sandwich': 'Bicky Burger', '_id': '67c9be8a387e701279a70647', 'ingredients': ['pork', 'chicken as food', 'horse meat']}, {'sandwich': 'Big Buford', '_id': '67c9be8a387e701279a70648', 'ingredients': ['mustard', 'mayonnaise', 'beef', 'red onion', 'iceberg lettuce', 'pickled cucumber', 'American cheese', 'tomato', 'ketchup']}, {'sandwich': 'Big Mac Bao', '_id': '67c9be8a387e701279a70649', 'ingredients': ['lettuce', 'beef', 'Cheddar cheese', 'pickled cucumber', 'flour', 'onion']}, {'sandwich': "Big N' Tasty", '_id': '67c9be8a387e701279a7064a', 'ingredients': ['Emmental', 'neata', 'tomato', 'onion', 'salad']}, {'sandwich': 'BK Stacker', '_id': '67c9be8b387e701279a7064b', 'ingredients': ['meat']}, {'sandwich': 'BLAT', '_id': '67c9be8b387e701279a7064c', 'ingredients': ['BLT', 'avocado']}, {'sandwich': 'BLT', '_id': '67c9be8b387e701279a7064d', 'ingredients': ['lettuce', 'mayonnaise', 'tomato', 'bacon']}, {'sandwich': 'boerewors roll', '_id': '67c9be8b387e701279a7064e', 'ingredients': ['boerewors']}, {'sandwich': 'Bondiola sandwich', '_id': '67c9be8b387e701279a7064f', 'ingredients': ['Bondiola']}, {'sandwich': 'Bosna', '_id': '67c9be8b387e701279a70650', 'ingredients': ['mustard', 'Allium', 'Bratwurst']}, {'sandwich': 'breakfast roll', '_id': '67c9be8b387e701279a70651', 'ingredients': ['Irish breakfast']}, {'sandwich': 'Buck Double', '_id': '67c9be8c387e701279a70652', 'ingredients': ['mustard', 'pickled cucumber', 'American cheese', 'ground beef', 'ketchup']}, {'sandwich': 'buffalo burger', '_id': '67c9be8c387e701279a70653', 'ingredients': ['Bison bison', 'bison meat']}, {'sandwich': 'bun kebab', '_id': '67c9be8c387e701279a70654', 'ingredients': ['lentil']}, {'sandwich': 'burrito', '_id': '67c9be8c387e701279a70655', 'ingredients': ['stuffing']}, {'sandwich': 'butifarra', '_id': '67c9be8c387e701279a70656', 'ingredients': ['salsa criolla', 'salsa criolla', 'salsa criolla', 'salsa criolla', 'jamón del país', 'jamón del país', 'jamón del país', 'jamón del país']}, {'sandwich': 'Butterbrot', '_id': '67c9be8c387e701279a70657', 'ingredients': ['butter']}, {'sandwich': 'Buttery Jack', '_id': '67c9be8c387e701279a70658', 'ingredients': ['iceberg lettuce', 'garlic butter', 'Swiss cheeses', 'tomato', 'ketchup', 'hamburger']}, {'sandwich': 'bánh mì', '_id': '67c9be8d387e701279a7 ...
# Ingrédient tomate: [{'food_name': 'Confitted oil tomatoes', 'nutrients': [{'nutrient_name': 'Protein', 'value': '1.200', 'unit': 'g'}, {'nutrient_name': 'Iron', 'value': '0.001', 'unit': 'g'}, {'nutrient_name': 'Calories', 'value': '23.000', 'unit': 'kcal'}, {'nutrient_name': 'Calcium', 'value': '0.013', 'unit': 'g'}, {'nutrient_name': 'Sodium', 'value': '0.013', 'unit': 'g'}, {'nutrient_name': 'Fiber', 'value': '1.100', 'unit': 'g'}, {'nutrient_name': 'Potassium', 'value': '0.204', 'unit': 'g'}, {'nutrient_name': 'Vitamin_a', 'value': '0.000', 'unit': 'g'}, {'nutrient_name': 'Vitamin_c', 'value': '0.023', 'unit': 'g'}, {'nutrient_name': 'Polyunsaturated_fat', 'value': '0.081', 'unit': 'g'}, {'nutrient_name': 'Carbohydrate', 'value': '5.100', 'unit': 'g'}, {'nutrient_name': 'Sugar', 'value': '4.000', 'unit': 'g'}, {'nutrient_name': 'Monounsaturated_fat', 'value': '0.030', 'unit': 'g'}, {'nutrient_name': 'Saturated_fat', 'value': '0.028', 'unit': 'g'}, {'nutrient_name': 'Fat', 'value': '0.200', 'unit': 'g'}, {'nutrient_name': 'Cholesterol', 'value': '0.000', 'unit': 'g'}]}, {'food_name': 'tomato', 'nutrients': [{'nutrient_name': 'Calories', 'value': '18.000', 'unit': 'kcal'}, {'nutrient_name': 'Protein', 'value': '0.880', 'unit': 'g'}, {'nutrient_name': 'Carbohydrate', 'value': '3.920', 'unit': 'g'}, {'nutrient_name': 'Fat', 'value': '0.200', 'unit': 'g'}, {'nutrient_name': 'Fiber', 'value': '1.200', 'unit': 'g'}, {'nutrient_name': 'Potassium', 'value': '0.237', 'unit': 'g'}, {'nutrient_name': 'Sugar', 'value': '2.630', 'unit': 'g'}, {'nutrient_name': 'Vitamin_a', 'value': '0.000', 'unit': 'g'}, {'nutrient_name': 'Iron', 'value': '0.000', 'unit': 'g'}, {'nutrient_name': 'Vitamin_c', 'value': '0.013', 'unit': 'g'}, {'nutrient_name': 'Cholesterol', 'value': '0.000', 'unit': 'g'}, {'nutrient_name': 'Saturated_fat', 'value': '0.046', 'unit': 'g'}, {'nutrient_name': 'Sodium', 'value': '0.005', 'unit': 'g'}, {'nutrient_name': 'Polyunsaturated_fat', 'value': '0.135', 'unit': 'g'}, {'nutrient_name': 'Monounsaturated_fat', 'value': '0.051', 'unit': 'g'}, {'nutrient_name': 'Calcium', 'value': '0.010', 'unit': 'g'}]}, {'food_name': 'tomato coulis', 'nutrients': [{'nutrient_name': 'Calories', 'value': '95.000', 'unit': 'kcal'}, {'nutrient_name': 'Protein', 'value': '4.120', 'unit': 'g'}, {'nutrient_name': 'Saturated_fat', 'value': '0.072', 'unit': 'g'}, {'nutrient_name': 'Carbohydrate', 'value': '22.450', 'unit': 'g'}, {'nutrient_name': 'Sodium', 'value': '0.070', 'unit': 'g'}, {'nutrient_name': 'Fat', 'value': '0.520', 'unit': 'g'}, {'nutrient_name': 'Potassium', 'value': '1.098', 'unit': 'g'}, {'nutrient_name': 'Fiber', 'value': '4.800', 'unit': 'g'}, {'nutrient_name': 'Sugar', 'value': '12.080', 'unit': 'g'}, {'nutrient_name': 'Cholesterol', 'value': '0.000', 'unit': 'g'}, {'nutrient_name': 'Calcium', 'value': '0.045', 'unit': 'g'}, {'nutrient_name': 'Vitamin_a', 'value': '0.000', 'unit': 'g'}, {'nutrient_name': 'Vitamin_c', 'value': '0.026', 'unit': 'g'}, {'nutrient_name': 'Iron', 'value': '0.004', 'unit': 'g'}, {'nutrient_name': 'Polyunsaturated_fat', 'value': '0.215', 'unit': 'g'}, {'nutrient_name': 'Monounsaturated_fat', 'value': '0.078', 'unit': 'g'}]}, {'food_name': 'tomatoes', 'nutrients': [{'nutrient_name': 'Vitamin_c', 'value': '0.013', 'unit': 'g'}, {'nutrient_name': 'Fiber', 'value': '1.200', 'unit': 'g'}, {'nutrient_name': 'Sugar', 'value': '2.630', 'unit': 'g'}, {'nutrient_name': 'Sodium', 'value': '0.005', 'unit': 'g'}, {'nutrient_name': 'Saturated_fat', 'value': '0.046', 'unit': 'g'}, {'nutrient_name': 'Calcium', 'value': '0.010', 'unit': 'g'}, {'nutrient_name': 'Potassium', 'value': '0.237', 'unit': 'g'}, {'nutrient_name': 'Cholesterol', 'value': '0.000', 'unit': 'g'}, {'nutrient_name': 'Polyunsaturated_fat', 'value': '0.135', 'unit': 'g'}, {'nutrient_name': 'Carbohydrate', 'value': '3.920', 'unit': 'g'}, {'nutrient_name': 'Calories', 'value': '18.000', 'unit': 'kcal'}, {'nutrient_name': 'Vitamin_a', 'value': '0.000', 'u ...
